# %% [markdown]
# # 1.1 Introduction
#
# ## Task 1.1P
# **Name: Hashaam Khan**
# **S223871946**
# **s223871946.deakin.edu.au**
# **SIT731 PostGrad**
# ## **Introduction**
# This report analyzes **Bitcoin's daily closing prices** using **NumPy and Matplotlib**. The goal is to extract meaningful insights by calculating statistical measures, visualizing trends, and identifying unusual price movements (outliers). The dataset consists of BTC-USD closing prices from **January 1, 2023, to the present**.
#
# The analysis includes:
# - **Basic statistical measures** (mean, median, quartiles, standard deviation, etc.).
# - **Trend visualization** for Q3 2023 and comparison across all four quarters.
# - **Box plot analysis** of daily price changes to identify market volatility.
# - **Outlier detection** to highlight unusual price movements.
#
# By completing this task, we develop skills in **data processing with NumPy, statistical analysis, and visualization**—essential for real-world data science applications.

# %% [markdown]
# ## Task 2.1
# **Downloading and cleaning daily close BTC-to-USD data, from 2023-01-01 up to this day**
# Data was downloaded and cleaned manually leaving only the close column and Date.

# %% [markdown]
# # Task 2.2
# **Using numpy.genfromtxt or numpy.loadtxt to read the above BTC-to-USD data as a numpy vector
# named rates.**

# %%
import numpy as np
import matplotlib.pyplot as plt
file_path = "BTC-USD-Close.csv"
rates = np.loadtxt(file_path, delimiter=',')

# %% [markdown]
# ## Task 2.3
# **Now for the 3rd Quarter we will display**
# * arithmetic mean ,
# * minimum,
# * the first quartile,
# * median,
# * the third quartile,
# * maximum,
# * standard deviation,
# * interquartile range.

# %%
# Extracting Q3 2023 data (
q3_rates = rates[181:273]
# Computing the required aggregates
arithmetic_mean = np.mean(q3_rates)
minimum = np.min(q3_rates)
q1 = np.percentile(q3_rates, 25)
median = np.median(q3_rates)
q3 = np.percentile(q3_rates, 75)
maximum = np.max(q3_rates)
std_dev = np.std(q3_rates)
iqr = q3 - q1

# Displaying aggregates
print("## Aggregates for Q3 2023")
print(f"Arithmetic Mean: {arithmetic_mean:.2f}")
print(f"Minimum: {minimum:.2f}")
print(f"Q1: {q1:.2f}")
print(f"Median: {median:.2f}")
print(f"Q3: {q3:.2f}")
print(f"Maximum: {maximum:.2f}")
print(f"Standard Deviation: {std_dev:.2f}")
print(f"Interquartile Range (IQR): {iqr:.2f}")
# Out:
# ## Aggregates for Q3 2023
# Arithmetic Mean: 28091.33
# Minimum: 25162.65
# Q1: 26225.56
# Median: 28871.82
# Q3: 29767.07
# Maximum: 31476.05
# Standard Deviation: 1827.04
# Interquartile Range (IQR): 3541.51

# %% [markdown]
# ## 2.4:
# **Using Matplotlib we will draw Q2 2023 Data**

# %%
# Defining days for Q3 2023 (starting from day 182 as day 1)
days = np.arange(182, 274)
# Ploting Q3 2023 BTC closing prices
plt.figure(figsize=(10, 5))
plt.plot(days, q3_rates, color='red', linestyle='-', label="BTC-USD Close Prices")
plt.title("BTC-USD Closing Prices in Q3 2023")
plt.xlabel("Days (from July 1, 2023)")
plt.ylabel("Closing Price (USD)")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# The graph shows how Bitcoin's price changed from July to September 2023. At the start, the price stayed between $29,000 and 31,000 with small ups and downs. Around Day 220, there was a big drop below 26,000, likely due to market changes or investor reactions. After that, the price moved up and down but didn’t fully recover, ending just under 27,000. This means Bitcoin had a tough time in Q3, with a sudden crash and some small recovery.

# %% [markdown]
# ## 2.5
# **Finding the day on which Bitcoin was at the highest and also at the lowest**

# %%
# Finding the day numbers for the lowest and highest prices in Q3 2023
min_day = 182 + np.argmin(q3_rates)
max_day = 182 + np.argmax(q3_rates)
print(f"\nLowest Price was on day {min_day} ({minimum:.2f})")
print(f"Highest Price was on day {max_day} ({maximum:.2f})")
# Out:
# Lowest Price was on day 254 (25162.65)
# Highest Price was on day 194 (31476.05)

# %% [markdown]
# ## 2.6
# **Now plotting for Q1 Q2 and Q4 also**

# %%
# Defining quarter indices
q1_rates = rates[:90]
q2_rates = rates[90:181]
q4_rates = rates[273:356]
# Defining corresponding day ranges
q1_days = np.arange(1, 91)
q2_days = np.arange(91, 182)
q4_days = np.arange(274, 274 + len(q4_rates))

# %%
# Ploting all quarters for comparison
plt.figure(figsize=(12, 6))
plt.plot(q1_days, q1_rates, color='blue', linestyle='-', label="Q1 2023")
plt.plot(q2_days, q2_rates, color='green', linestyle='-', label="Q2 2023")
plt.plot(days, q3_rates, color='red', linestyle='-', label="Q3 2023")
plt.plot(q4_days, q4_rates, color='purple', linestyle='-', label="Q4 2023")
plt.title("BTC-USD Closing Prices for Each Quarter in 2023")
plt.xlabel("Days (from Jan 1, 2023)")
plt.ylabel("Closing Price (USD)")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Bitcoin Price Trends in 2023
#
# The graph shows how Bitcoin’s price changed throughout **2023**, divided into four quarters:
#
# - **Q1 (Blue):** Bitcoin started the year at a low price but **steadily increased** to around **28,000**.
# - **Q2 (Green):** Prices remained **stable**, fluctuating between **27,000 and 31,000**.
# - **Q3 (Red):** A **decline** happened, with Bitcoin dropping below **26,000**.
# - **Q4 (Purple):** A **strong recovery** occurred, with Bitcoin **rising above 40,000**.
#
# ### **Key Takeaways**
# Bitcoin had **a strong start, a stable middle, a weak third quarter,

# %% [markdown]
# ## Task 3 for PostGrad Students
# ## 3.1
# **Drawing a boxplot for Q3 with AM as green x**

# %%
# Computing daily price changes in Q3 using numpy.diff
q3_changes = np.diff(q3_rates)

# Creating a horizontal box plot
plt.figure(figsize=(8, 4))
plt.boxplot(q3_changes, vert=False, patch_artist=True)
mean_change = np.mean(q3_changes)
plt.plot(mean_change, 1, 'gx', markersize=12, label="Mean Change")
plt.title("Distribution of BTC-to-USD Daily Price Changes in Q3 2023")
plt.xlabel("Daily Price Change (USD)")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Distribution of BTC-to-USD Daily Price Changes in Q3 2023
#
# This box plot shows the **daily price changes** of Bitcoin in **Q3 2023**.
#
# - The **blue box** represents the **middle 50% of the data** (interquartile range, IQR), meaning most daily price changes fall within this range.
# - The **orange line** inside the box is the **median**, showing the middle value of the daily changes.
# - The **whiskers** extend to the smallest and largest values within **1.5× IQR**, covering most normal price changes.
# - The **circles (outliers)** represent extreme price movements beyond the expected range, indicating sudden spikes or drops in Bitcoin's price.
#
# ### **Key Takeaways**
# - Most daily price changes were within a **moderate range**, suggesting stability in BTC's price movements.
# - There are **several outliers**, indicating days with **unusual price spikes or crashes**.
# - The presence of negative and positive outliers suggests **high volatility** in Q3, with some days experiencing **sharp losses or gains**.
#
# Overall, this plot highlights **Bitcoin's price fluctuations in Q3 2023**, showing both normal daily movements and exceptional price swings.

# %% [markdown]
# ## 3.2:
# **Computing no of Outliers in Q3**

# %%
# Computing outliers 
q1_changes = np.percentile(q3_changes, 25)
q3_changes_75 = np.percentile(q3_changes, 75)  
iqr_changes = q3_changes_75 - q1_changes

# Defining outlier thresholds
lower_bound = q1_changes - 1.5 * iqr_changes
upper_bound = q3_changes_75 + 1.5 * iqr_changes

# Identifying outliers correctly from the actual daily changes
outliers = q3_changes[(q3_changes < lower_bound) | (q3_changes > upper_bound)]
num_outliers = len(outliers)

print(f"\nNumber of Outliers in Q3 2023: {num_outliers}")
# Out:
# Number of Outliers in Q3 2023: 16

# %% [markdown]
# ### **What Do the Outliers Mean?**
# Outliers in the box plot represent **unusual daily price changes** in Bitcoin during **Q3 2023**. These extreme movements could be caused by:
#
# - **Market News & Events** – Major announcements, regulations, or institutional investments.
# - **Economic Factors** – Interest rate changes, inflation reports, or global financial trends.
# - **Market Manipulation** – Large trades by big investors (whales) creating sudden spikes or drops.
# - **Crypto-Specific Events** – Exchange hacks, security issues, or major upgrades.
#
# ### **Key Insights**
# - **More outliers** → Higher volatility with frequent big price swings.
# - **Fewer outliers** → A more stable market with fewer unexpected moves.
# - **Negative outliers** → Sudden crashes due to panic selling.
# - **Positive outliers** → Sharp price increases from strong buying activity.
#
# Outliers help us understand **how stable or unpredictable Bitcoin was in Q3 2023**. 🚀📉📈

# %% [markdown]
# ## **Summary & Discussion**
# This analysis provided insights into **Bitcoin's price trends in 2023**, with a focus on **Q3 2023**. We observed that:
# - **Bitcoin experienced steady growth in Q1, stability in Q2, a drop in Q3, and a strong surge in Q4**.
# - **Q3 saw a noticeable decline**, with prices falling below **$26,000**, but some recovery was observed later.
# - The **box plot analysis** showed that **daily price changes were mostly stable**, but some extreme movements (outliers) indicated **high volatility** on certain days.
#
# ### **Key Takeaways**
# - **Bitcoin’s price follows a cyclical pattern**, influenced by market trends and external factors.
# - **Outliers highlight significant market events**, such as major price crashes or surges.
# - **NumPy is powerful for data processing**, enabling efficient calculations without loops.
#
# ### **Future Improvements**
# - Expanding the analysis to include **moving averages** and other **technical indicators**.
# - Comparing BTC trends with other **cryptocurrencies** or **economic factors**.
# - Using **machine learning** to predict price trends based on past data.
#
# This task demonstrated the importance of **data wrangling, visualization, and statistical analysis** in understanding financial trends. 🚀📊
